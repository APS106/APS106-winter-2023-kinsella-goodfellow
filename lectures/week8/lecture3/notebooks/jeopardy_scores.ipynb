# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 8 | Lecture 3 (8.3) - Jeopardy

# %%
import utils

# %%
scores = {
    'mechanical': sum([]),
    'chemical': sum([-500, -500, -500, -500, 1000, -1000, 1000, 1000, 5000]),
    'civil': sum([-500, 500, -250, -250]),
    'mineral': sum([]),
    'materials': sum([]),
    'industrial': sum([]),
    'track1': sum([500, 500, 1000, 1000, 250, 500])
}

utils.plot_scores(scores)
