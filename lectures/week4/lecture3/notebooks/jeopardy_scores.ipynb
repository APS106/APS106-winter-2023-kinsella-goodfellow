# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 4 | Lecture 3 (4.3) - Jeopardy

# %%
import utils

# %%
scores = {
    'mechanical': sum([1000]),
    'chemical': sum([250, 1000, 1000, 500]),
    'civil': sum([1000, -500, 500, -500, -500]),
    'mineral': sum([1000, 500]),
    'materials': sum([]),
    'industrial': sum([]),
    'track1': sum([-1000, 500, -500, 500, -1000, 5000])
}

utils.plot_scores(scores)
